# %%
jackdaw = "James Bond me voilà"
print(jackdaw)
# Out:
# James Bond me voilà

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv("imdb_top_250.csv")

print(df.info())

RT_Movie = df.groupby('Year')['Runtime'].mean()
YE_Movie = np.sort(df['Year'].drop_duplicates())
VO_Movie = df.groupby('Year')['Rating'].mean()

Min_Year = df['Year'].max()
print(f"Minimum Year: {Min_Year}")

print(RT_Movie)
print(YE_Movie)
print(VO_Movie)
plt.figure(facecolor='#F8F9FA')
ax = plt.gca()
ax.set_facecolor("#F8F9FA")

coor = 1960


plt.plot(YE_Movie,RT_Movie,color="#23282d")

plt.xlabel("Release year")
plt.ylabel("Runtime in minutes")

plt.title("Average evolution of the runtime of the top 250 by IMDB")

plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     250 non-null    int64
#  1   Title    250 non-null    object
#  2   Year     250 non-null    int64
#  3   Rating   250 non-null    float64
#  4   Runtime  250 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 9.9+ KB
# None
# Minimum Year: 2020
# Year
# 1921     68.0
# 1924     45.0
# 1925     95.0
# 1926     78.0
# 1927    153.0
#         ...
# 2016    130.0
# 2017    119.0
# 2018    133.0
# 2019    125.5
# 2020    160.0
# Name: Runtime, Length: 84, dtype: float64
# [1921 1924 1925 1926 1927 1928 1931 1934 1936 1939 1940 1941 1942 1944
#  1946 1948 1949 1950 1951 1952 1953 1954 1955 1957 1958 1959 1960 1961
#  1962 1963 1965 1966 1967 1968 1971 1972 1973 1974 1975 1976 1977 1978
#  1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992
# ...
